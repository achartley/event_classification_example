# %% [markdown]
# # Classification using dense neural network (fully connected)
# For this exercise we'll be using [Keras](https://keras.io/).. In addition you need either [TensorFlow](https://www.tensorflow.org/) or [PyTorch](https://pytorch.org/)
# as the underlying framework. Or, you can also continue with scikit-learn, which also has dense / fully connected networks implemented.

# %% [markdown]
# ## Normalization of image data
# We apply the same normalization as for logistic regression. Recall that we have saved this function in a file
# called `helper_functions.py`, and can import and use it directly from there.

# %% [markdown]
# ## Numpy approach

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, InputLayer
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score, 
                             matthews_corrcoef, roc_curve, roc_auc_score)
from helper_functions import normalize_image_data, plot_roc_auc, noise_gen
from timeit import default_timer as timer

# %load_ext autoreload
# %autoreload 2

# %%
# Load images and labels.
DATA_PATH = "../data/"

images = np.load(DATA_PATH+"nimages_training.npy")
labels = np.load(DATA_PATH+"labels_training.npy")

rimages = np.load(DATA_PATH+"images_200k.npy")
rlabels = np.load(DATA_PATH+"labels_200k.npy")


# Just like with logistic regression, we need to reshape the images to
# be one-dimensional for the input to the model.
images = images.reshape(images.shape[0], 256)
rimages = rimages.reshape(rimages.shape[0], 256)

# Split the training indices into training and validation. 
# Validate with 25% of the data (default). Can be adjusted.
x_idx = np.arange(images.shape[0])
train_idx, val_idx, not_used1, not_used2 = train_test_split(x_idx, x_idx, test_size = 0.25)

# %%
#rdfile = np.genfromtxt(DATA_PATH+"ratiodist.txt")
#images_test = np.load(DATA_PATH+"images_test.npy")
#images = images.reshape(images.shape[0], 256)

#nimages = []


#This takes a long time (1:20m for 8000 matrices) so we'll save it to a file

#for image in images:
#    nimages.append(image*noise_gen(rdfile))

#np.save(DATA_PATH+"nimages_test",nimages)

# %% [markdown]
# ### Build a model
# We're going to start off with a simple feed-forward neural network one hidden layer. This is a binary classifier, so
# we techincally only need it to output one number.
#
# What about the number of nodes in the hidden input layer?
# The top post in [this](https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw) stackexchange question points to some good sources of information about this.
#
# > There are some empirically-derived rules-of-thumb, of these, the most commonly relied on is 'the optimal size of the hidden layer is usually between the size of the input and size of the output layers'
# (Jeff Heaton, author of [Introduction to Neural Networks in Java](https://www.heatonresearch.com/book/) offers a few more.)

# %%
# Init the Sequential model
model = Sequential()
# Add Input layer
model.add(InputLayer(input_shape=(images.shape[1],)))

# Add hidden layer
model.add(Dense(64, activation='relu'))

# Add output layer.
model.add(Dense(1, activation='sigmoid'))

# Finally, compile the model and print a summary. Loss function and optimizer is set during compilation.
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 16,513
# Trainable params: 16,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model
# The fit() function returns a history object that we'll store to plot how the training developed with epochs.
# First we need to set som training parameters.
#
# Note that if you would like to change something about the the model and run training again, you must
# re-compile the model. Otherwise you will essentially just be doubling the number of epochs.

# %%
# Set parameters for the training run. For the small set of 10k events you can probably get 
# away with even 100 epochs in a fairly small time, depending on your CPU.
epochs = 100
batch_size = 32

# %%
# The validation_data keywork expects a 'tuple' (val_x, val_y) so we make one on the fly
history = model.fit(
    x=normalize_image_data(images[train_idx]),
    y=labels[train_idx],
    validation_data=(normalize_image_data(images[val_idx]), labels[val_idx]),
    epochs=epochs,
    batch_size=batch_size,
)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.6463 - accuracy: 0.6798 - val_loss: 0.5784 - val_accuracy: 0.6855
# Epoch 2/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.5428 - accuracy: 0.7320 - val_loss: 0.6163 - val_accuracy: 0.6870
# Epoch 3/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.5048 - accuracy: 0.7357 - val_loss: 0.6589 - val_accuracy: 0.6940
# Epoch 4/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4963 - accuracy: 0.7423 - val_loss: 0.7436 - val_accuracy: 0.6690
# Epoch 5/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4940 - accuracy: 0.7388 - val_loss: 0.6821 - val_accuracy: 0.6960
# Epoch 6/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4907 - accuracy: 0.7427 - val_loss: 0.7064 - val_accuracy: 0.6905
# Epoch 7/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4893 - accuracy: 0.7467 - val_loss: 0.7002 - val_accuracy: 0.6945
# Epoch 8/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4881 - accuracy: 0.7463 - val_loss: 0.7126 - val_accuracy: 0.6915
# Epoch 9/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4875 - accuracy: 0.7462 - val_loss: 0.7159 - val_accuracy: 0.6895
# Epoch 10/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4859 - accuracy: 0.7488 - val_loss: 0.7209 - val_accuracy: 0.6885
# Epoch 11/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7488 - val_loss: 0.7198 - val_accuracy: 0.6890
# Epoch 12/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4839 - accuracy: 0.7482 - val_loss: 0.7193 - val_accuracy: 0.6905
# Epoch 13/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4837 - accuracy: 0.7510 - val_loss: 0.7260 - val_accuracy: 0.6870
# Epoch 14/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4830 - accuracy: 0.7493 - val_loss: 0.6922 - val_accuracy: 0.6985
# Epoch 15/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4826 - accuracy: 0.7487 - val_loss: 0.7763 - val_accuracy: 0.6740
# Epoch 16/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7500 - val_loss: 0.7139 - val_accuracy: 0.6915
# Epoch 17/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4808 - accuracy: 0.7528 - val_loss: 0.7639 - val_accuracy: 0.6785
# Epoch 18/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4805 - accuracy: 0.7550 - val_loss: 0.7285 - val_accuracy: 0.6895
# Epoch 19/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7550 - val_loss: 0.7239 - val_accuracy: 0.6895
# Epoch 20/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4793 - accuracy: 0.7535 - val_loss: 0.7224 - val_accuracy: 0.6910
# Epoch 21/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4795 - accuracy: 0.7523 - val_loss: 0.7196 - val_accuracy: 0.6925
# Epoch 22/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4786 - accuracy: 0.7542 - val_loss: 0.7034 - val_accuracy: 0.6950
# Epoch 23/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4796 - accuracy: 0.7545 - val_loss: 0.7369 - val_accuracy: 0.6885
# Epoch 24/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.7567 - val_loss: 0.7447 - val_accuracy: 0.6860
# Epoch 25/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7548 - val_loss: 0.7744 - val_accuracy: 0.6775
# Epoch 26/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4785 - accuracy: 0.7548 - val_loss: 0.7355 - val_accuracy: 0.6890
# Epoch 27/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4772 - accuracy: 0.7573 - val_loss: 0.7709 - val_accuracy: 0.6775
# Epoch 28/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4786 - accuracy: 0.7587 - val_loss: 0.7909 - val_accuracy: 0.6750
# Epoch 29/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4780 - accuracy: 0.7558 - val_loss: 0.7284 - val_accuracy: 0.6925
# Epoch 30/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4771 - accuracy: 0.7578 - val_loss: 0.7118 - val_accuracy: 0.6935
# Epoch 31/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4772 - accuracy: 0.7583 - val_loss: 0.7455 - val_accuracy: 0.6890
# Epoch 32/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4763 - accuracy: 0.7570 - val_loss: 0.7490 - val_accuracy: 0.6875
# Epoch 33/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4767 - accuracy: 0.7603 - val_loss: 0.7247 - val_accuracy: 0.6920
# Epoch 34/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4763 - accuracy: 0.7575 - val_loss: 0.7425 - val_accuracy: 0.6915
# Epoch 35/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7622 - val_loss: 0.7512 - val_accuracy: 0.6870
# Epoch 36/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4756 - accuracy: 0.7580 - val_loss: 0.7566 - val_accuracy: 0.6845
# Epoch 37/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4766 - accuracy: 0.7590 - val_loss: 0.7346 - val_accuracy: 0.6920
# Epoch 38/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4750 - accuracy: 0.7617 - val_loss: 0.7185 - val_accuracy: 0.6935
# Epoch 39/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4752 - accuracy: 0.7638 - val_loss: 0.7351 - val_accuracy: 0.6915
# Epoch 40/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.7618 - val_loss: 0.7193 - val_accuracy: 0.6925
# Epoch 41/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7630 - val_loss: 0.7452 - val_accuracy: 0.6880
# Epoch 42/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.7620 - val_loss: 0.6971 - val_accuracy: 0.6995
# Epoch 43/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4737 - accuracy: 0.7622 - val_loss: 0.7294 - val_accuracy: 0.6915
# Epoch 44/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.7642 - val_loss: 0.7222 - val_accuracy: 0.6905
# Epoch 45/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.7593 - val_loss: 0.7301 - val_accuracy: 0.6920
# Epoch 46/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4740 - accuracy: 0.7640 - val_loss: 0.7412 - val_accuracy: 0.6905
# Epoch 47/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.7672 - val_loss: 0.7742 - val_accuracy: 0.6805
# Epoch 48/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.7635 - val_loss: 0.7576 - val_accuracy: 0.6845
# Epoch 49/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4735 - accuracy: 0.7648 - val_loss: 0.7407 - val_accuracy: 0.6910
# Epoch 50/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.7632 - val_loss: 0.7242 - val_accuracy: 0.6930
# Epoch 51/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4716 - accuracy: 0.7652 - val_loss: 0.7643 - val_accuracy: 0.6825
# Epoch 52/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7650 - val_loss: 0.7225 - val_accuracy: 0.6945
# Epoch 53/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4708 - accuracy: 0.7655 - val_loss: 0.7427 - val_accuracy: 0.6870
# Epoch 54/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4702 - accuracy: 0.7658 - val_loss: 0.7258 - val_accuracy: 0.6915
# Epoch 55/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4702 - accuracy: 0.7648 - val_loss: 0.7550 - val_accuracy: 0.6855
# Epoch 56/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4685 - accuracy: 0.7695 - val_loss: 0.7731 - val_accuracy: 0.6825
# Epoch 57/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4702 - accuracy: 0.7657 - val_loss: 0.7707 - val_accuracy: 0.6830
# Epoch 58/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4686 - accuracy: 0.7667 - val_loss: 0.7059 - val_accuracy: 0.7010
# Epoch 59/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4690 - accuracy: 0.7688 - val_loss: 0.7249 - val_accuracy: 0.6935
# Epoch 60/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.7672 - val_loss: 0.7459 - val_accuracy: 0.6885
# Epoch 61/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4678 - accuracy: 0.7673 - val_loss: 0.6980 - val_accuracy: 0.7010
# Epoch 62/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4673 - accuracy: 0.7695 - val_loss: 0.7249 - val_accuracy: 0.6935
# Epoch 63/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4672 - accuracy: 0.7678 - val_loss: 0.7198 - val_accuracy: 0.6935
# Epoch 64/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4675 - accuracy: 0.7688 - val_loss: 0.7186 - val_accuracy: 0.6945
# Epoch 65/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4663 - accuracy: 0.7698 - val_loss: 0.7154 - val_accuracy: 0.6950
# Epoch 66/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4655 - accuracy: 0.7723 - val_loss: 0.7029 - val_accuracy: 0.7005
# Epoch 67/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4656 - accuracy: 0.7713 - val_loss: 0.7109 - val_accuracy: 0.6960
# Epoch 68/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4644 - accuracy: 0.7707 - val_loss: 0.7466 - val_accuracy: 0.6870
# Epoch 69/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4641 - accuracy: 0.7733 - val_loss: 0.7190 - val_accuracy: 0.6930
# Epoch 70/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4641 - accuracy: 0.7730 - val_loss: 0.7337 - val_accuracy: 0.6925
# Epoch 71/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4629 - accuracy: 0.7707 - val_loss: 0.7564 - val_accuracy: 0.6855
# Epoch 72/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4631 - accuracy: 0.7705 - val_loss: 0.7367 - val_accuracy: 0.6890
# Epoch 73/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.7762 - val_loss: 0.7202 - val_accuracy: 0.6925
# Epoch 74/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4627 - accuracy: 0.7705 - val_loss: 0.6904 - val_accuracy: 0.7050
# Epoch 75/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7713 - val_loss: 0.7195 - val_accuracy: 0.6940
# Epoch 76/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7707 - val_loss: 0.7047 - val_accuracy: 0.7000
# Epoch 77/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7722 - val_loss: 0.7133 - val_accuracy: 0.6925
# Epoch 78/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4608 - accuracy: 0.7752 - val_loss: 0.7321 - val_accuracy: 0.6885
# Epoch 79/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4605 - accuracy: 0.7753 - val_loss: 0.7271 - val_accuracy: 0.6900
# Epoch 80/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7720 - val_loss: 0.6919 - val_accuracy: 0.7015
# Epoch 81/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4591 - accuracy: 0.7747 - val_loss: 0.7488 - val_accuracy: 0.6845
# Epoch 82/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.7798 - val_loss: 0.6903 - val_accuracy: 0.7040
# Epoch 83/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4584 - accuracy: 0.7777 - val_loss: 0.7174 - val_accuracy: 0.6920
# Epoch 84/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4582 - accuracy: 0.7758 - val_loss: 0.7207 - val_accuracy: 0.6900
# Epoch 85/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4574 - accuracy: 0.7765 - val_loss: 0.7350 - val_accuracy: 0.6875
# Epoch 86/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4571 - accuracy: 0.7777 - val_loss: 0.7292 - val_accuracy: 0.6895
# Epoch 87/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4567 - accuracy: 0.7767 - val_loss: 0.7054 - val_accuracy: 0.6950
# Epoch 88/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4574 - accuracy: 0.7775 - val_loss: 0.7005 - val_accuracy: 0.6945
# Epoch 89/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.7785 - val_loss: 0.7212 - val_accuracy: 0.6895
# Epoch 90/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4551 - accuracy: 0.7765 - val_loss: 0.7221 - val_accuracy: 0.6895
# Epoch 91/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.7795 - val_loss: 0.7116 - val_accuracy: 0.6940
# Epoch 92/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4550 - accuracy: 0.7788 - val_loss: 0.7046 - val_accuracy: 0.6970
# Epoch 93/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.7812 - val_loss: 0.7158 - val_accuracy: 0.6920
# Epoch 94/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4536 - accuracy: 0.7793 - val_loss: 0.7108 - val_accuracy: 0.6935
# Epoch 95/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4541 - accuracy: 0.7795 - val_loss: 0.6615 - val_accuracy: 0.7130
# Epoch 96/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4527 - accuracy: 0.7832 - val_loss: 0.7414 - val_accuracy: 0.6890
# Epoch 97/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.7825 - val_loss: 0.7320 - val_accuracy: 0.6890
# Epoch 98/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7807 - val_loss: 0.7315 - val_accuracy: 0.6900
# Epoch 99/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4518 - accuracy: 0.7805 - val_loss: 0.7257 - val_accuracy: 0.6910
# Epoch 100/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4510 - accuracy: 0.7802 - val_loss: 0.6959 - val_accuracy: 0.6975

# %% [markdown]
# ### Evaluate the model
# Let's use the history object to plot how the loss and accuracy changed during training.
# The history contains a dictionary of the currently applied metrics as keys. In this case we have the
# keys "loss", "accuracy", "val_loss", and "val_accuracy". "loss" and "accuracy" pertain to the training data, while
# "val_loss" and "val_accuracy" are the metrics for the validation data we provided.

# %%
# Plot loss and val_loss as one plot, and accuracy and val_accuracy as another, side-by-side.
# We'll also save this plot as plot_history() in the helper_functions file, so any time we need to
# plot the history object like this we can just call that function and pass the history object as
# an argument.
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
num_epochs = len(history.history['loss'])
ax[0].plot(history.history['loss'], label='training')
ax[0].plot(history.history['val_loss'], label='validation')
ax[0].set_title("Model loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].set_xticks(np.arange(num_epochs))
ax[0].legend()

ax[1].plot(history.history['accuracy'], label='training')
ax[1].plot(history.history['val_accuracy'], label='validation')
ax[1].set_title("Model accburacy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].set_xticks(np.arange(num_epochs))
ax[1].legend()

# %% [markdown]
# The plotting function will only plot these two metrics regardless of how many other metrics we add to the model,
# but it's a starting point that can be extended as you might add more metrics.

# %%
# Predict on the validation set
pred = model.predict([normalize_image_data(rimages)])
# Convert sigmoid values from prediction to integers so it works with the function.
result = pred > 0.5

# %% [markdown]
# ## Collection of metrics
# Check out the notebook on logistic regression for details around the metrics.

# %%
accuracy = accuracy_score(rlabels, result)
confmat = confusion_matrix(rlabels, result)
f1 = f1_score(rlabels, result)
mcc = matthews_corrcoef(rlabels, result)

# %%
# Print the metrics in an orderly fashion
print("Confusion matrix:\n", confmat)
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
# Out:
# Confusion matrix:
#  [[12957 87043]
#  [  733 99267]]
# Accuracy: 0.56112
# F1-score: 0.6934232126017255
# MCC: 0.24204356127831958

# %% [markdown]
# ## ROC-Curve and Area Under Curve

# %%
# Use the function we saved from the notebook on logistic regression
plot_roc_auc(rlabels, pred)
